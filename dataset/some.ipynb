# %%
from datasetload import load_dataset

ds = load_dataset("../transform")
# Out:
#  65%|██████▌   | 726/1109 [00:00<00:00, 1547.38it/s]/home/petr/projects/mltests/.venv/lib/python3.12/site-packages/dataclasses_json/core.py:201: RuntimeWarning: 'NoneType' object value of non-optional type lines detected when decoding BPMNFlow.
#   warnings.warn(
# 100%|██████████| 1109/1109 [00:00<00:00, 1491.30it/s]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cnts = np.array([
    l
    for d in ds
    for p in d['diagram'].processes
    for f in p.flows
    if f and f.lines and (l := len(f.lines)) > 1
])
plt.hist(cnts, bins=20)
# Out:
# (array([1.0709e+04, 4.2730e+03, 2.6620e+03, 1.7000e+02, 0.0000e+00,
#         6.7000e+01, 2.3000e+01, 7.0000e+00, 3.0000e+00, 0.0000e+00,
#         6.0000e+00, 4.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([ 2. ,  2.8,  3.6,  4.4,  5.2,  6. ,  6.8,  7.6,  8.4,  9.2, 10. ,
#         10.8, 11.6, 12.4, 13.2, 14. , 14.8, 15.6, 16.4, 17.2, 18. ]),
#  <BarContainer object of 20 artists>)
